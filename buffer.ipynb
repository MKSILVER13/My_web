# %%
import networkx as nx
from pyvis.network import Network
import fitz  # PyMuPDF
import os
import re
import sys
import json 


def extract_structured_text_from_pdf(pdf_path):
    """
    Extract text from PDF with formatting information using PyMuPDF.
    Uses geometric analysis to detect underlined text.
    Returns a list of dictionaries with text and its formatting properties.
    """
    try:
        # print(f"Opening PDF file: {pdf_path}")
        doc = fitz.open(pdf_path)
        # print(f"PDF has {len(doc)} pages")
        
        structured_text = []
        
        # First pass: determine maximum font size for reference
        max_font_size = 0
        for page in doc:
            blocks = page.get_text("dict")["blocks"]
            for block in blocks:
                if "lines" in block:
                    for line in block["lines"]:
                        for span in line["spans"]:
                            max_font_size = max(max_font_size, span["size"])
        # print(f"Maximum font size detected: {max_font_size}")
        
        # Process each page: extract text spans and detect underlines via drawing objects.
        for page_num, page in enumerate(doc):
            # Get drawing objects and filter for those that appear to be underlines.
            drawings = page.get_drawings()
            underline_rects = []
            for d in drawings:
                # Look for filled rectangles (type 'f') which might be drawn as underlines.
                if d.get("type") == "f":
                    for item in d.get("items", []):
                        if item[0] == "re":
                            rect = item[1]
                            # Heuristic: if the rectangle is very short in height, consider it an underline.
                            if rect.height < 5:
                                underline_rects.append(rect)
            
            blocks = page.get_text("dict")["blocks"]
            for block in blocks:
                if "lines" in block:
                    for line in block["lines"]:
                        line_text = ""
                        is_bold = False
                        is_underlined = False
                        font_size = 0
                        font_used = ""
                        span_bboxes = []
                        
                        # Process each span within the line.
                        for span in line["spans"]:
                            if "bold" in span["font"].lower():
                                is_bold = True
                            line_text += span["text"] + " "
                            font_size = max(font_size, span["size"])
                            font_used = span["font"]
                            span_bboxes.append(span["bbox"])
                        
                        # Compute the union of the bounding boxes for the whole line.
                        if span_bboxes:
                            x0 = min(b[0] for b in span_bboxes)
                            y0 = min(b[1] for b in span_bboxes)
                            x1 = max(b[2] for b in span_bboxes)
                            y1 = max(b[3] for b in span_bboxes)
                            line_bbox = (x0, y0, x1, y1)
                        else:
                            line_bbox = None
                        
                        # Heuristic: if any underline rectangle overlaps horizontally
                        # and its top is within 5 units of the text bbox bottom, mark as underlined.
                        if line_bbox:
                            for rect in underline_rects:
                                overlap = min(line_bbox[2], rect.x1) - max(line_bbox[0], rect.x0)
                                if overlap > 0 and abs(rect.y0 - line_bbox[3]) < 5:
                                    is_underlined = True
                                    break
                        
                        line_text = line_text.strip()
                        if line_text:
                            structured_text.append({
                                "text": line_text,
                                "font": font_used,
                                "font_size": font_size,
                                "is_bold": is_bold,
                                "is_underlined": is_underlined,
                                "page": page_num + 1
                            })
        
        # print(f"Extracted {len(structured_text)} text elements")
        return structured_text
    except Exception as e:
        # print(f"Error extracting PDF text: {e}")
        raise e

# %%
hi = extract_structured_text_from_pdf(r'C:\Users\bilas\OneDrive\Documents\GENAI\my_web\iitg.pdf')

# %%
with open('output.json', 'w') as f:
    json.dump(hi, f, indent=4)

# %%
from unstructured.partition.auto import partition
from spacy import load
import networkx as nx
import matplotlib.pyplot as plt
from typing import List, Tuple

def create_knowledge_graph(text_file: str) -> nx.Graph:
    # Load SpaCy model for English
    nlp = load("en_core_web_sm")
    
    # Parse document using Unstructured
    elements = partition(filename=text_file)
    text = " ".join([str(element) for element in elements])
    
    # Process text with SpaCy
    doc = nlp(text)
    
    # Create graph
    G = nx.Graph()
    
    # Extract entities and relationships
    for sent in doc.sents:
        entities = [(ent.text, ent.label_) for ent in sent.ents]
        
        # Add nodes and edges
        for i in range(len(entities)):
            G.add_node(entities[i][0], type=entities[i][1])
            if i > 0:
                G.add_edge(entities[i-1][0], entities[i][0])
    
    return G

def visualize_graph(G: nx.Graph):
    plt.figure(figsize=(12, 8))
    pos = nx.spring_layout(G)
    nx.draw(G, pos, with_labels=True, node_color='lightblue', 
            node_size=1500, font_size=8)
    plt.title("Knowledge Graph")
    plt.show()

def main():
    # Example usage
    file_path = "output.txtc"  # Replace with your text file
    graph = create_knowledge_graph(file_path)
    visualize_graph(graph)

if __name__ == "__main__":
    main()

# %%
# !pip install unstructured spacy networkx matplotlib
# Out:
# Collecting unstructured
#   Downloading unstructured-0.17.2-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: spacy in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (3.7.2)
# Requirement already satisfied: networkx in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (3.1)
# Requirement already satisfied: matplotlib in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (3.9.2)
# Requirement already satisfied: chardet in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (from unstructured) (5.2.0)
# Collecting filetype (from unstructured)
#   Using cached filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting python-magic (from unstructured)
#   Using cached python_magic-0.4.27-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: lxml in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (from unstructured) (5.3.1)
# Requirement already satisfied: nltk in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (from unstructured) (3.9.1)
# Requirement already satisfied: requests in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (from unstructured) (2.32.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (from unstructured) (4.12.3)
# Collecting emoji (from unstructured)
#   Using cached emoji-2.14.1-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: dataclasses-json in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (from unstructured) (0.6.7)
# Collecting python-iso639 (from unstructured)
#   Using cached python_iso639-2025.2.18-py3-none-any.whl.metadata (14 kB)
# Collecting langdetect (from unstructured)
#   Using cached langdetect-1.0.9.tar.gz (981 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numpy in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (from unstructured) (1.26.4)
# Collecting rapidfuzz (from unstructured)
#   Downloading rapidfuzz-3.13.0-cp312-cp312-win_amd64.whl.metadata (12 kB)
# Collecting backoff (from unstructured)
#   Using cached backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: typing-extensions in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (from unstructured) (4.12.2)
# Collecting unstructured-client (from unstructured)
#   Downloading unstructured_client-0.33.0-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: wrapt in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (from unstructured) (1.16.0)
# Requirement already satisfied: tqdm in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (from unstructured) (4.66.5)
# Requirement already satisfied: psutil in c:\users\bilas\appdata\roaming\python\python312\site-packages (from unstructured) (5.9.8)
# Collecting python-oxmsg (from unstructured)
#   Using cached python_oxmsg-0.0.2-py3-none-any.whl.metadata (5.0 kB)
# Collecting html5lib (from unstructured)
#   Using cached html5lib-1.1-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (from spacy) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (from spacy) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (from spacy) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (from spacy) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (from spacy) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (from spacy) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (from spacy) (6.4.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (from spacy) (2.9.2)
# Requirement already satisfied: jinja2 in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (from spacy) (70.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\bilas\appdata\roaming\python\python312\site-packages (from spacy) (24.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (from spacy) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: pillow>=8 in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\bilas\appdata\roaming\python\python312\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: language-data>=1.2 in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.23.4)
# Requirement already satisfied: six>=1.5 in c:\users\bilas\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (from requests->unstructured) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (from requests->unstructured) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (from requests->unstructured) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (from requests->unstructured) (2024.6.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy) (0.1.5)
# Requirement already satisfied: colorama in c:\users\bilas\appdata\roaming\python\python312\site-packages (from tqdm->unstructured) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (from beautifulsoup4->unstructured) (2.6)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (from dataclasses-json->unstructured) (3.23.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (from dataclasses-json->unstructured) (0.9.0)
# Requirement already satisfied: webencodings in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (from html5lib->unstructured) (0.5.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (from jinja2->spacy) (2.1.5)
# Requirement already satisfied: joblib in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (from nltk->unstructured) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (from nltk->unstructured) (2024.9.11)
# Collecting olefile (from python-oxmsg->unstructured)
#   Using cached olefile-0.47-py2.py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: aiofiles>=24.1.0 in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (from unstructured-client->unstructured) (24.1.0)
# Collecting cryptography>=3.1 (from unstructured-client->unstructured)
#   Downloading cryptography-44.0.2-cp39-abi3-win_amd64.whl.metadata (5.7 kB)
# Collecting eval-type-backport>=0.2.0 (from unstructured-client->unstructured)
#   Using cached eval_type_backport-0.2.2-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (from unstructured-client->unstructured) (0.27.2)
# Requirement already satisfied: nest-asyncio>=1.6.0 in c:\users\bilas\appdata\roaming\python\python312\site-packages (from unstructured-client->unstructured) (1.6.0)
# Collecting pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 (from spacy)
#   Downloading pydantic-2.11.3-py3-none-any.whl.metadata (65 kB)
# Requirement already satisfied: pypdf>=4.0 in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (from unstructured-client->unstructured) (5.3.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (from unstructured-client->unstructured) (1.0.0)
# Collecting typing-inspection>=0.4.0 (from unstructured-client->unstructured)
#   Using cached typing_inspection-0.4.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting pydantic-core==2.33.1 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy)
#   Downloading pydantic_core-2.33.1-cp312-cp312-win_amd64.whl.metadata (6.9 kB)
# Requirement already satisfied: cffi>=1.12 in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (from cryptography>=3.1->unstructured-client->unstructured) (1.17.1)
# Requirement already satisfied: anyio in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.27.0->unstructured-client->unstructured) (4.6.0)
# Requirement already satisfied: httpcore==1.* in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.27.0->unstructured-client->unstructured) (1.0.5)
# Requirement already satisfied: sniffio in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.27.0->unstructured-client->unstructured) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->unstructured-client->unstructured) (0.14.0)
# Requirement already satisfied: marisa-trie>=1.1.0 in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->unstructured) (1.0.0)
# Requirement already satisfied: pycparser in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (from cffi>=1.12->cryptography>=3.1->unstructured-client->unstructured) (2.22)
# Downloading unstructured-0.17.2-py3-none-any.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----------- ---------------------------- 0.5/1.8 MB 2.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.3/1.8 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 3.5 MB/s eta 0:00:00
# Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# Using cached emoji-2.14.1-py3-none-any.whl (590 kB)
# Using cached filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Using cached html5lib-1.1-py2.py3-none-any.whl (112 kB)
# Using cached python_iso639-2025.2.18-py3-none-any.whl (167 kB)
# Using cached python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Using cached python_oxmsg-0.0.2-py3-none-any.whl (31 kB)
# Downloading rapidfuzz-3.13.0-cp312-cp312-win_amd64.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ------------------- -------------------- 0.8/1.6 MB 3.7 MB/s eta 0:00:01
#    -------------------------------------- - 1.6/1.6 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 3.5 MB/s eta 0:00:00
# Downloading unstructured_client-0.33.0-py3-none-any.whl (181 kB)
# Downloading pydantic-2.11.3-py3-none-any.whl (443 kB)
# Downloading pydantic_core-2.33.1-cp312-cp312-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------- ----------------------- 0.8/2.0 MB 3.4 MB/s eta 0:00:01
#    -------------------------- ------------- 1.3/2.0 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 3.3 MB/s eta 0:00:00
# Downloading cryptography-44.0.2-cp39-abi3-win_amd64.whl (3.2 MB)
#    ---------------------------------------- 0.0/3.2 MB ? eta -:--:--
#    ------ --------------------------------- 0.5/3.2 MB 2.8 MB/s eta 0:00:01
#    ------------- -------------------------- 1.0/3.2 MB 2.8 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.8/3.2 MB 3.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 2.4/3.2 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  3.1/3.2 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------- 3.2/3.2 MB 3.0 MB/s eta 0:00:00
# Using cached eval_type_backport-0.2.2-py3-none-any.whl (5.8 kB)
# Using cached typing_inspection-0.4.0-py3-none-any.whl (14 kB)
# Using cached olefile-0.47-py2.py3-none-any.whl (114 kB)
# Building wheels for collected packages: langdetect
#   Building wheel for langdetect (setup.py): started
#   Building wheel for langdetect (setup.py): finished with status 'done'
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993255 sha256=9a71cff18a8656459e7bc1ff7e62ff90ae9290a3bb33f4f4b7809e4fc6adf847
#   Stored in directory: c:\users\bilas\appdata\local\pip\cache\wheels\c1\67\88\e844b5b022812e15a52e4eaa38a1e709e99f06f6639d7e3ba7
# Successfully built langdetect
# Installing collected packages: filetype, typing-inspection, rapidfuzz, python-magic, python-iso639, pydantic-core, olefile, langdetect, html5lib, eval-type-backport, emoji, backoff, python-oxmsg, pydantic, cryptography, unstructured-client, unstructured
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.23.4
#     Uninstalling pydantic_core-2.23.4:
#       Successfully uninstalled pydantic_core-2.23.4
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.9.2
#     Uninstalling pydantic-2.9.2:
#       Successfully uninstalled pydantic-2.9.2
# Successfully installed backoff-2.2.1 cryptography-44.0.2 emoji-2.14.1 eval-type-backport-0.2.2 filetype-1.2.0 html5lib-1.1 langdetect-1.0.9 olefile-0.47 pydantic-2.11.3 pydantic-core-2.33.1 python-iso639-2025.2.18 python-magic-0.4.27 python-oxmsg-0.0.2 rapidfuzz-3.13.0 typing-inspection-0.4.0 unstructured-0.17.2 unstructured-client-0.33.0
