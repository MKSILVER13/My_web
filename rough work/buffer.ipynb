# %%
import networkx as nx
from pyvis.network import Network
import pytesseract
from PIL import Image
import fitz  # PyMuPDF
import os
import re
import sys
import json 


def ocr_force(doc):
    """
    Process a PDF document and apply OCR to pages with no text blocks.
    For pages that need OCR, creates a structured text dictionary.
    For pages with existing text, keeps the original page.
    Returns a list containing processed pages.
    """
    final_doc = []
    page_num = 0
    for page in doc:
        page_num += 1
        full_ocr_text = ""
        # Check if the page has text blocks
        need_ocr = False
        blocks = page.get_text("dict")["blocks"]
        if blocks == []:
            need_ocr = True
        if need_ocr:
            pixmap = page.get_pixmap()
            img = Image.frombytes("RGB", [pixmap.width, pixmap.height], pixmap.samples)
            try:
                page_text = pytesseract.image_to_string(img)
                full_ocr_text += f"==Start of OCR for page {page_num + 1}==\n"
                full_ocr_text += page_text
                full_ocr_text += f"\n==End of OCR for page {page_num + 1}==\n\n"
                # print(f"Page {page_num + 1} OCR text: {page_text}")
                
                # Create a structured representation of the OCR text
                ocr_result = {
                    "text": page_text,
                    "font": "OCR-detected",
                    "font_size": 10.0,  # Default font size
                    "is_bold": False,   # We can't detect bold with basic OCR
                    "is_underlined": False,  # We can't detect underlines with basic OCR
                    "page": page_num,
                    "source": "ocr"     # Mark as OCR source for reference
                }
                final_doc.append(ocr_result)
            except Exception as e:
                print(f"Error during OCR on page {page_num + 1}: {e}")
                # Add an empty result to keep page ordering consistent
                final_doc.append({
                    "text": f"[OCR ERROR on page {page_num + 1}]",
                    "font": "OCR-error",
                    "font_size": 10.0,
                    "is_bold": False,
                    "is_underlined": False,
                    "page": page_num,
                    "source": "ocr-error"
                })
        else:
            final_doc.append(page)
    
    return final_doc

def extract_structured_text_from_pdf(pdf_path):
    """
    Extract text from PDF with formatting information using PyMuPDF.
    Uses geometric analysis to detect underlined text.
    Returns a list of dictionaries with text and its formatting properties.
    """
    try:
        # print(f"Opening PDF file: {pdf_path}")
        doc = fitz.open(pdf_path)
        # print(f"PDF has {len(doc)} pages")
        
        # Process document with OCR for pages that need it
        processed_doc = ocr_force(doc)
        
        structured_text = []
        
        # First pass: determine maximum font size for reference
        max_font_size = 0
        for page in doc:
            blocks = page.get_text("dict")["blocks"]
            for block in blocks:
                if "lines" in block:
                    for line in block["lines"]:
                        for span in line["spans"]:
                            max_font_size = max(max_font_size, span["size"])
        # print(f"Maximum font size detected: {max_font_size}")
        
        # Process each page: extract text spans and detect underlines via drawing objects.
        for page_num, item in enumerate(processed_doc):
            # Check if this is an OCR result (dictionary) or a regular page
            if isinstance(item, dict) and "source" in item and item["source"] in ["ocr", "ocr-error"]:
                # This is an OCR result, add it directly to structured text
                structured_text.append(item)
                continue            # Check if this is an OCR result (dictionary) or a regular page
            if isinstance(item, dict) and "source" in item and item["source"] in ["ocr", "ocr-error"]:
                # This is an OCR result, add it directly to structured text
                structured_text.append(item)
                continue
                
            # This is a regular page, process it normally
            page = item
            
            # Get drawing objects and filter for those that appear to be underlines.
            drawings = page.get_drawings()
            underline_rects = []
            for d in drawings:
                # Look for filled rectangles (type 'f') which might be drawn as underlines.
                if d.get("type") == "f":
                    for item in d.get("items", []):
                        if item[0] == "re":
                            rect = item[1]
                            # Heuristic: if the rectangle is very short in height, consider it an underline.
                            if rect.height < 5:
                                underline_rects.append(rect)
            
            blocks = page.get_text("dict")["blocks"]
            for block in blocks:
                if "lines" in block:
                    for line in block["lines"]:
                        line_text = ""
                        is_bold = False
                        is_underlined = False
                        font_size = 0
                        font_used = ""
                        span_bboxes = []
                        
                        # Process each span within the line.
                        for span in line["spans"]:
                            if "bold" in span["font"].lower():
                                is_bold = True
                            line_text += span["text"] + " "
                            font_size = max(font_size, span["size"])
                            font_used = span["font"]
                            span_bboxes.append(span["bbox"])
                        
                        # Compute the union of the bounding boxes for the whole line.
                        if span_bboxes:
                            x0 = min(b[0] for b in span_bboxes)
                            y0 = min(b[1] for b in span_bboxes)
                            x1 = max(b[2] for b in span_bboxes)
                            y1 = max(b[3] for b in span_bboxes)
                            line_bbox = (x0, y0, x1, y1)
                        else:
                            line_bbox = None
                        
                        # Heuristic: if any underline rectangle overlaps horizontally
                        # and its top is within 5 units of the text bbox bottom, mark as underlined.
                        if line_bbox:
                            for rect in underline_rects:
                                overlap = min(line_bbox[2], rect.x1) - max(line_bbox[0], rect.x0)
                                if overlap > 0 and abs(rect.y0 - line_bbox[3]) < 5:
                                    is_underlined = True
                                    break
                        
                        line_text = line_text.strip()
                        if line_text:
                            structured_text.append({
                                "text": line_text,
                                "font": font_used,
                                "font_size": font_size,
                                "is_bold": is_bold,
                                "is_underlined": is_underlined,
                                "page": page_num + 1,
                                "source": "text"  # Mark as normal text extraction
                            })
          # print(f"Extracted {len(structured_text)} text elements")
        return structured_text
    except Exception as e:
        print(f"Error extracting PDF text: {e}")
        raise e

# %%
extract_structured_text_from_pdf(r'C:\Users\bilas\OneDrive\Documents\GENAI\my_web\Pathway_MidEval_Report.pdf')
# Out:
# [{'text': 'Dynamic Agentic RAG with Pathway',
#   'font': 'NimbusRomNo9L-Medi',
#   'font_size': 14.346199989318848,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'Team 67',
#   'font': 'NimbusRomNo9L-Medi',
#   'font_size': 9.962599754333496,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'Abstract',
#   'font': 'NimbusRomNo9L-Medi',
#   'font_size': 11.9552001953125,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'In this work, we aim to develop an End-to-End',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'Agentic RAG system utilizing Pathway’s real-',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'time data processing capabilities. We identify',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'areas within the legal domain where current RAG',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.862470626831055,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'systems could be improved upon. Our application',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.862470626831055,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'should have intelligent decision-making beyond',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.046924591064453,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'basic retrieval.',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.962599754333496,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': '1. Introduction',
#   'font': 'NimbusRomNo9L-Medi',
#   'font_size': 11.9552001953125,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': '1.1. Problem Statement',
#   'font': 'NimbusRomNo9L-Medi',
#   'font_size': 9.962599754333496,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'This problem statement focuses on the development of an',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'Agent-based Retrieval-Augmented Generation (RAG)',
#   'font': 'NimbusRomNo9L-Medi',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'system using the Pathway framework. The challenge in-',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'volves introducing novel solutions to the domain and techni-',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.862470626831055,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'cal issues to produce a highly accurate  question-answering',
#   'font': 'NimbusRomNo9L-Medi',
#   'font_size': 9.862470626831055,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'model . Overall, the target is the creation of robust, effi-',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'cient, and flexible AI agents, which are capable of  decision-',
#   'font': 'NimbusRomNo9L-Medi',
#   'font_size': 9.867501258850098,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'making  and adaptive learning from real-time data streams.',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.962599754333496,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': '1.2. Use Case Selection and Novelty',
#   'font': 'NimbusRomNo9L-Medi',
#   'font_size': 9.962599754333496,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'Our chosen domain is the legal sector, selected for its com-',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.96757984161377,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'plexity and the high accuracy and contextual understanding',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.902643203735352,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'required to interpret legal texts effectively. Key challenges',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.992443084716797,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'in this domain include handling specific terminology, inter-',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.952631950378418,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'preting precedents, supporting legal reasoning, and gener-',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'ating precise citations. Additionally, all RAG systems face',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.977532386779785,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'the fundamental challenge of low accuracy, which becomes',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.89763069152832,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'particularly critical in legal applications.',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.962599754333496,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'While Legal AI tools like Contract Lifecycle Management',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.002370834350586,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': '(CLM) systems and legal research tools are available, a gap',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.89261531829834,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'remains in their capabilities. These tools are effective for',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'generating standard, high-volume contracts but fall short in',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.92266845703125,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'crafting unique, research-intensive, and bespoke contracts.',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.022196769714355,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'Furthermore, none of these solutions are tailored to the',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'Indian legal context and judiciary system, which has its own',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.862470626831055,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'regulatory standards and complexities.',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.962599754333496,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'Our solution addresses these gaps by combining CLM and',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.987475395202637,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'legal research functionalities into a unified tool specifically',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.942654609680176,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'designed for drafting custom contracts that align with up-to-',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.862470626831055,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'date Indian regulations. With features like real-time policy',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.987475395202637,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'updates, in-depth case research, and automated contract',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'generation, this platform enables legal professionals to craft',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.867501258850098,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'contracts tailored to unique legal scenarios. Leveraging an',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.997407913208008,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'Agentic RAG system, our solution is optimized for accuracy',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.862470626831055,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'and adaptability in this demanding legal domain.',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.962599754333496,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': '1.3. Solution Overview',
#   'font': 'NimbusRomNo9L-Medi',
#   'font_size': 9.962599754333496,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'Our solution focuses on two primary aspects of current is-',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'sues in legal question answering. The first is  poor retrieval ,',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.862470626831055,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'arising from  poor embedding quality  due to legal jargon,',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.032095909118652,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'along with the  complexity of legal texts . This complexity',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.017244338989258,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'also leads to the second issue of  poor multi-hop reasoning',
#   'font': 'NimbusRomNo9L-Medi',
#   'font_size': 9.867501258850098,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'abilities. While this is an issue that affects LLM based ques-',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.862470626831055,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'tion answering in all domains, it is especially pronounced',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'in the legal space, due to the highly interconnected nature',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'of most case docs.',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.962599754333496,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'We deal with the former by using improved legal-specific',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'legal embedding models, such as  voyage-law-2 . We also',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'experiment with reranking software for the same. The latter',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.872529029846191,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'issue is dealt with by creating sophisticated agentic RAG',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'systems that deal with multi-hop reasoning tasks in a step-',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.032095909118652,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'by-step manner. Additionally, latency-related improvements',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.862470626831055,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'are introduced by using  LLMCompiler .',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.962599754333496,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': '2. Literature Review',
#   'font': 'NimbusRomNo9L-Medi',
#   'font_size': 11.9552001953125,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': '2.1. Parsing and Preprocessing',
#   'font': 'NimbusRomNo9L-Medi',
#   'font_size': 9.962599754333496,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'Parsing legal PDFs for RAG workflows is challenging due to',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.862470626831055,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'complex layouts with nested headers, footnotes, and embed-',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.862470626831055,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'ded tables. Traditional parsers like  PyPDF2  and  PDFMiner',
#   'font': 'NimbusRomNo9L-Medi',
#   'font_size': 9.862470626831055,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'can extract text but lack structural sensitivity, struggling with',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.862470626831055,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'layout-heavy elements such as nested headers and irregular',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.927669525146484,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'tables.  Camelot  performs moderately well on simple ta-',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'bles but is less effective for complex layouts. Vision-based',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.962599754333496,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'language models (VLLMs) offer some promise but face',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'challenges in production-level accuracy and efficiency.',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.962599754333496,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'To address these limitations, we developed a hybrid pipeline',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.862470626831055,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'using  Unstructured  and  Docling .  Unstructured  parses text',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.862470626831055,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'into structured elements (headers, titles, etc.) in JSON for-',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.022196769714355,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'mat but underperforms on table extraction, so we skip tables',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.862470626831055,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'in its parsing. For detailed table extraction, we use  Docling ,',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.877554893493652,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'running it in parallel and iterating over Unstructured’s out-',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.007330894470215,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'put to replace or add table data from Docling’s Markdown',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.012289047241211,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': '1',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.962599754333496,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 1,
#   'source': 'text'},
#  {'text': 'Team 67',
#   'font': 'NimbusRomNo9L-Medi',
#   'font_size': 8.966400146484375,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'output. In cases where Unstructured misses tables, we use',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.02714729309082,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'regex  to identify table-like structures and substitute them',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'with Docling data.',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.962599754333496,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'Finally, we experiment with  FAIR’s Nougat , which en-',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'hances document structure preservation by converting PDFs',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.862470626831055,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'into a specialized markdown format, maintaining layout ac-',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.9176664352417,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'curacy, and improving table extraction. This hybrid method',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.89261531829834,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'balances accuracy with efficiency, addressing the unique',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'complexities of legal PDFs.',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.962599754333496,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': '2.2. Chunking',
#   'font': 'NimbusRomNo9L-Medi',
#   'font_size': 9.962599754333496,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'Chunking within the RAG framework serves as a vital tech-',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.89763069152832,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'nique for enhancing the efficiency of data retrieval, espe-',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'cially in complex and highly structured domains such as',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'legal documentation. Earlier methods focused on funda-',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'mental approaches to divide texts based on straightforward',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.952631950378418,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'segmentation criteria, which were effective but not sufficient',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.862470626831055,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'for handling the intricacies of legal language and references.',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.862470626831055,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'Initial trials demonstrated that simplistic chunking strategies',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.862470626831055,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'often resulted in  fragmented information retrieval , lead-',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.022196769714355,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'ing to a  loss of contextual integrity . This compromised',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'the quality of the generated responses, especially when ad-',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.992443084716797,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'dressing multifaceted legal queries that demanded nuanced',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.942654609680176,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'understanding and precision. ( Li et al.  ( 2024 ))',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.962599754333496,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'Recognizing these challenges, several chunking techniques',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.932666778564453,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'were tried to address the limitations identified during pre-',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'liminary testing. Existing chunking techniques are tried to',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.012289047241211,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'test their performance for this task in the legal domain.  Se-',
#   'font': 'NimbusRomNo9L-Medi',
#   'font_size': 9.982504844665527,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'mantic chunking  helps in maintaining relevance between',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.022196769714355,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'the sentences of the documents, which helps maintain  con-',
#   'font': 'NimbusRomNo9L-Medi',
#   'font_size': 9.977532386779785,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'textual reference in legal documents , but, this only tackles',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.862470626831055,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'one of the existing problems, which is determining an accu-',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.89763069152832,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'rate breakpoint to segment the document.',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.962599754333496,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'The other problem that exists is the  loss of context  since',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'legal documents require a lot of previous context as well',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'due to the long length of the documents.',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.962599754333496,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'The results are shown in  Table 1  :',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.962599754333496,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'Chunking Techniques',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 8.966400146484375,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'Score',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 8.966400146484375,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'Semantic',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 8.966400146484375,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': '0.5184648034046766',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 8.966400146484375,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'Hierarchical',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 8.966400146484375,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': '0.46874114629227864',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 8.966400146484375,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'Table 1.  Different chunking techniques performance',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 8.966400146484375,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'Legal documents often have a complex structure, including',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.927669525146484,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'sections, subsections, clauses, and annexes.  Hierarchi-',
#   'font': 'NimbusRomNo9L-Medi',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'cal chunking  mirrors this structure by processing text at',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'multiple levels. Initially, larger sections are chunked and',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'analyzed, and then these can be further broken down into',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'subsections and clauses. This approach allows for main-',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'taining the  integrity of legal arguments and references',
#   'font': 'NimbusRomNo9L-Medi',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'throughout the document. This can also help in maintaining',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.862470626831055,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'contextual relevance.',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.962599754333496,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'Table 2  represents the average scores of semantic chunking',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.937662124633789,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'for different breakpoint thresholds for several queries. This',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.92266845703125,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'infers that the scores reduce with the reducing thresholds',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'due to less relevance in the chunks. Thus, we aim to perform',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.862470626831055,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'the scores of the model at lesser thresholds.',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.962599754333496,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'Threshold(in percent) Factual Correctness Semantic Similarity*',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 8.966400146484375,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': '95',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 8.966400146484375,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': '0.48',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 8.966400146484375,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': '0.880',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 8.966400146484375,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': '90',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 8.966400146484375,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': '0.46',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 8.966400146484375,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': '0.878',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 8.966400146484375,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': '85',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 8.966400146484375,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': '0.42',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 8.966400146484375,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': '0.872',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 8.966400146484375,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': '80',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 8.966400146484375,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': '0.33',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 8.966400146484375,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': '0.866',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 8.966400146484375,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'Table 2.  Semantic Chunking granularity',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 8.966400146484375,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'Dealing with the second issue is actually a challenging',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'task. The simple RAG pipeline of  chunking-embedding-',
#   'font': 'NimbusRomNo9L-Medi',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'retrieving-generating  can destroy the long-distance con-',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'textual dependencies.',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.962599754333496,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': '2.3. Retrievers',
#   'font': 'NimbusRomNo9L-Medi',
#   'font_size': 9.962599754333496,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'Retrieval-augmented generation (RAG) relies on sophis-',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'ticated retrieval techniques to select candidate contexts',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'that enhance user queries. Foundational retrievers, such',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'as  TF-IDF  and  BM25  Kalra et al.  ( 2024 ) use lexical',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'similarities for query-document matching. For baseline',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'comparisons, we evaluated  rank-bm25 , a widely used',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'implementation integrated into libraries like LangChain and',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.862470626831055,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'Llama-Index.',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.962599754333496,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'Dense Passage Retrieval',
#   'font': 'NimbusRomNo9L-Medi',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'Karpukhin et al.  ( 2020 )',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'employs dense vector embeddings for efficient retrieval',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'and is popular in RAG frameworks.',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'However, DPR',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'and similar methods are limited in  multi-hop  scenarios,',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'often trained independently for each hop, which can',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'undermine performance in complex multi-hop queries. To',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.02714729309082,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'address multi-hop retrieval, we explored  Beam Retrieval',
#   'font': 'NimbusRomNo9L-Medi',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'Zhang et al.  ( 2024a ), which uses an encoder and dual',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'classification heads to score hypotheses for each passage.',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'We also examined  SURE  Kim et al.  ( 2024a )  ,  a model',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'that generates and validates summaries for multi-answer',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'candidate sets, improving retrieval accuracy for intricate',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'texts, like  case law  documents, by summarizing content',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'before passing context to the generator.',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.962599754333496,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'In  legal RAG  frameworks,  HyPA RAG  Kalra et al.',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': '( 2024 ) stands out with a query complexity classifier for',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'adaptive parameter tuning, combining dense, sparse, and',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'knowledge graph retrieval. Initial experiments included',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'auto-merging techniques,',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'BM25,',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'and simple fusion',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'retrievers combining BM25 and DPR.',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.962599754333496,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': '2',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.962599754333496,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 2,
#   'source': 'text'},
#  {'text': 'Team 67',
#   'font': 'NimbusRomNo9L-Medi',
#   'font_size': 8.966400146484375,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 3,
#   'source': 'text'},
#  {'text': 'Retriever Score*',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 8.966400146484375,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 3,
#   'source': 'text'},
#  {'text': 'DPR',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 8.966400146484375,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 3,
#   'source': 'text'},
#  {'text': '0.743',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 8.966400146484375,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 3,
#   'source': 'text'},
#  {'text': 'ColBERT 0.689',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 8.966400146484375,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 3,
#   'source': 'text'},
#  {'text': 'FAISS',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 8.966400146484375,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 3,
#   'source': 'text'},
#  {'text': '0.636',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 8.966400146484375,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 3,
#   'source': 'text'},
#  {'text': 'BM25',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 8.966400146484375,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 3,
#   'source': 'text'},
#  {'text': '0.614',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 8.966400146484375,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 3,
#   'source': 'text'},
#  {'text': 'T5',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 8.966400146484375,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 3,
#   'source': 'text'},
#  {'text': '0.751',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 8.966400146484375,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 3,
#   'source': 'text'},
#  {'text': 'Table 3.  Retriever Performance Scores',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 8.966400146484375,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 3,
#   'source': 'text'},
#  {'text': 'Embedding Model',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 8.966400146484375,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 3,
#   'source': 'text'},
#  {'text': 'Score*',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 8.966400146484375,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 3,
#   'source': 'text'},
#  {'text': 'vstackai-law-1',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 8.966400146484375,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 3,
#   'source': 'text'},
#  {'text': '66.16',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 8.966400146484375,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 3,
#   'source': 'text'},
#  {'text': 'voyage-law-2',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 8.966400146484375,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 3,
#   'source': 'text'},
#  {'text': '65.39',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 8.966400146484375,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 3,
#   'source': 'text'},
#  {'text': 'e5-mistral-7b-instruct',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 8.966400146484375,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 3,
#   'source': 'text'},
#  {'text': '59.77',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 8.966400146484375,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 3,
#   'source': 'text'},
#  {'text': 'text-embedding-3-large 59.22',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 8.966400146484375,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 3,
#   'source': 'text'},
#  {'text': 'Table 4.  Embedding-based Retrieval Scores (MTEB-Law)',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 8.966400146484375,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 3,
#   'source': 'text'},
#  {'text': '2.4. Postprocessing',
#   'font': 'NimbusRomNo9L-Medi',
#   'font_size': 9.962599754333496,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 3,
#   'source': 'text'},
#  {'text': 'Rerankers can significantly improve the search quality be-',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.051863670349121,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 3,
#   'source': 'text'},
#  {'text': 'cause they operate at a sub-document and sub-query level,',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.037040710449219,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 3,
#   'source': 'text'},
#  {'text': 'meaning they look at the individual words and phrases, their',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.862470626831055,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 3,
#   'source': 'text'},
#  {'text': 'meanings, and how they relate to each other within the',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 3,
#   'source': 'text'},
#  {'text': 'query and the documents. This results in a more precise and',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.862470626831055,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 3,
#   'source': 'text'},
#  {'text': 'contextually relevant set of search results.',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.962599754333496,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 3,
#   'source': 'text'},
#  {'text': 'Most of the post-retrieval processing includes the usage',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 3,
#   'source': 'text'},
#  {'text': 'of rerankers. We experimented using various rankers.  Co-',
#   'font': 'NimbusRomNo9L-Medi',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 3,
#   'source': 'text'},
#  {'text': 'here ’s reranking tool  Cohere  ( 2024 ) uses advanced language',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.862470626831055,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 3,
#   'source': 'text'},
#  {'text': 'models to reorder lists based on contextual relevance, en-',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 3,
#   'source': 'text'},
#  {'text': 'hancing search accuracy and content discovery.  ColBERT',
#   'font': 'NimbusRomNo9L-Medi',
#   'font_size': 9.982504844665527,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 3,
#   'source': 'text'},
#  {'text': 'Santhanam et al.  ( 2022 ) encodes them into matrices of token-',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.862470626831055,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 3,
#   'source': 'text'},
#  {'text': 'level embeddings. At search time, it computes fine-grained',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.937662124633789,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 3,
#   'source': 'text'},
#  {'text': 'similarities between query and document tokens, allow-',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 3,
#   'source': 'text'},
#  {'text': 'ing for more precise relevance scoring.  FlagEmbedding ’s',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.992443084716797,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 3,
#   'source': 'text'},
#  {'text': 'reranking models operate as cross-encoders, evaluating the',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.952631950378418,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 3,
#   'source': 'text'},
#  {'text': 'relationship between a query and each retrieved document',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.017244338989258,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 3,
#   'source': 'text'},
#  {'text': 'to assign a relevance score. The  Jina  Reranker v2 is a',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 3,
#   'source': 'text'},
#  {'text': 'transformer-based model that has been fine-tuned for text',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 3,
#   'source': 'text'},
#  {'text': 'reranking tasks.  LongContextReorder  ensures that the',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 3,
#   'source': 'text'},
#  {'text': 'highest-scored (most relevant) nodes are positioned at the',
#   'font': 'NimbusRomNo9L-Regu',
# ...
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': 'gar, V. (2024). Similar cases recommendation using legal',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.862470626831055,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': 'knowledge graphs.',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.962599754333496,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': 'Finardi, P., Avila, L., Castaldoni, R., Gengo, P., Larcher, C.,',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.89763069152832,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': 'Piau, M., Costa, P., and Carid ´ a, V. (2024). The chronicles',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.962599754333496,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': 'of rag: The retriever, the chunk and the generator.',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.962599754333496,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': 'G ¨ unther, M., Mohr, I., Williams, D. J., Wang, B., and Xiao,',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.962599754333496,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': 'H. (2024). Late chunking: Contextual chunk embeddings',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.862470626831055,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': 'using long-context embedding models.',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.962599754333496,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': 'Jiang, Z., Sun, M., Liang, L., and Zhang, Z. (2024). Re-',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': 'trieve, summarize, plan: Advancing multi-hop question',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.046924591064453,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': 'answering with an iterative approach.',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.962599754333496,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': 'Kalra, R., Wu, Z., Gulley, A., Hilliard, A., Guan, X.,',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': 'Koshiyama, A., and Treleaven, P. (2024). Hypa-rag: A',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': 'hybrid parameter adaptive retrieval-augmented genera-',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': 'tion system for ai legal and policy applications.',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.962599754333496,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': 'Karpukhin, V., O ˘ guz, B., Min, S., Lewis, P., Wu, L., Edunov,',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.962599754333496,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': 'S., Chen, D., and tau Yih, W. (2020). Dense passage',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': 'retrieval for open-domain question answering.',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.962599754333496,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': 'Kim, J., Nam, J., Mo, S., Park, J., Lee, S.-W., Seo, M., Ha,',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.002370834350586,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': 'J.-W., and Shin, J. (2024a). Sure: Summarizing retrievals',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.862470626831055,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': 'using answer candidates for open-domain qa of llms.',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.962599754333496,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': 'Kim, S., Moon, S., Tabrizi, R., Lee, N., Mahoney, M. W.,',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': 'Keutzer, K., and Gholami, A. (2024b). An llm compiler',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.992443084716797,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': 'for parallel function calling.',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.962599754333496,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': 'Li, W., Li, J., Ma, W., and Liu, Y. (2024). Citation-enhanced',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.862470626831055,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': 'generation for llm-based chatbots.',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.962599754333496,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': 'Mamakas, D., Tsotsi, P., Androutsopoulos, I., and Chalkidis,',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.862470626831055,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': 'I. (2022). Processing long legal documents with pre-',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': 'trained transformers: Modding legalbert and longformer.',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.952631950378418,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': 'Mavromatis, C. and Karypis, G. (2024). Gnn-rag: Graph',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': 'neural retrieval for large language model reasoning.',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.962599754333496,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': 'Santhanam, K., Khattab, O., Saad-Falcon, J., Potts, C., and',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.952631950378418,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': 'Zaharia, M. (2022). Colbertv2: Effective and efficient',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': 'retrieval via lightweight late interaction.',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.962599754333496,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': 'Sarmah, B., Hall, B., Rao, R., Patel, S., Pasquali, S., and',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': 'Mehta, D. (2024). Hybridrag: Integrating knowledge',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': 'graphs and vector retrieval augmented generation for effi-',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.872529029846191,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': 'cient information extraction.',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.962599754333496,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': 'Shi, Y., Zi, X., Shi, Z., Zhang, H., Wu, Q., and Xu, M.',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': '(2024a). Enhancing retrieval and managing retrieval: A',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.032095909118652,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': 'four-module synergy for improved quality and efficiency',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.9176664352417,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': 'in rag systems.',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.962599754333496,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': 'Shi, Z., Ming, Y., Nguyen, X.-P., Liang, Y., and Joty, S.',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': '(2024b). Discovering the gems in early layers: Accelerat-',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.862470626831055,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': 'ing long-context llms with 1000x input token reduction.',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.962599754333496,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': 'Singh, I. S., Aggarwal, R., Allahverdiyev, I., Taha, M.,',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': 'Akalin, A., Zhu, K., and O’Brien, S. (2024). Chunkrag:',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.051863670349121,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': 'Novel llm-chunk filtering method for rag systems.',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.962599754333496,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': 'Wang, Z., Yuan, H., Dong, W., Cong, G., and Li, F. (2024).',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.96757984161377,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': 'Corag: A cost-constrained retrieval optimization system',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.977532386779785,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': 'for retrieval-augmented generation.',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.962599754333496,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': 'Wiratunga, N., Abeyratne, R., Jayawardena, L., Martin, K.,',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.952631950378418,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': 'Massie, S., Nkisi-Orji, I., Weerasinghe, R., Liret, A., and',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.89763069152832,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': 'Fleisch, B. (2024). Cbr-rag: Case-based reasoning for',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': 'retrieval augmented generation in llms for legal question',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.932666778564453,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': 'answering.',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.962599754333496,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': 'Wu, J., Yang, L., Ji, Y., Huang, W., Karlsson, B. F., and Oku-',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.862470626831055,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': 'mura, M. (2024). Gendec: A robust generative question-',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.962599754333496,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': 'decomposition method for multi-hop reasoning.',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.962599754333496,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': 'Zhang, J., Zhang, H., Zhang, D., Liu, Y., and Huang, S.',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': '(2024a). End-to-end beam retrieval for multi-hop ques-',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': 'tion answering.',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.962599754333496,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': 'Zhang, Y., Sun, R., Chen, Y., Pfister, T., Zhang, R., and Arik,',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.862470626831055,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': 'S. (2024b). Chain of agents: Large language models',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 10.061732292175293,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': 'collaborating on long-context tasks.',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.962599754333496,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': '6. Appendix',
#   'font': 'NimbusRomNo9L-Medi',
#   'font_size': 11.9552001953125,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': '6.1. Competitive Audit',
#   'font': 'NimbusRomNo9L-Medi',
#   'font_size': 9.962599754333496,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': '8',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.962599754333496,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 8,
#   'source': 'text'},
#  {'text': 'Team 67',
#   'font': 'NimbusRomNo9L-Medi',
#   'font_size': 8.966400146484375,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 9,
#   'source': 'text'},
#  {'text': 'Figure 4.  The competitive audit reveals a landscape where AI-driven legal tools focus on document review, contract lifecycle management,',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 8.966400146484375,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 9,
#   'source': 'text'},
#  {'text': 'and litigation support, with varying degrees of specialization. Our audit examined leading platforms such as Casetext, Luminance,',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.055620193481445,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 9,
#   'source': 'text'},
#  {'text': 'Ironclad, and Everlaw, assessing their unique selling points, feature sets, integrations, and user group focus. This analysis helps identify',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 8.961915969848633,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 9,
#   'source': 'text'},
#  {'text': 'key market gaps and strengths, guiding our product development to emphasize research-integrated contract drafting for non-standard,',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.055620193481445,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 9,
#   'source': 'text'},
#  {'text': 'compliance-focused legal documents.',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 8.966400146484375,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 9,
#   'source': 'text'},
#  {'text': '9',
#   'font': 'NimbusRomNo9L-Regu',
#   'font_size': 9.962599754333496,
#   'is_bold': False,
#   'is_underlined': False,
#   'page': 9,
#   'source': 'text'}]

# %%
# !pip install PyMuPDF Pillow pytesseract
# Out:
# Requirement already satisfied: PyMuPDF in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (1.25.4)
# Requirement already satisfied: Pillow in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (10.3.0)
# Requirement already satisfied: pytesseract in c:\users\bilas\appdata\local\programs\python\python312\lib\site-packages (0.3.13)
# Requirement already satisfied: packaging>=21.3 in c:\users\bilas\appdata\roaming\python\python312\site-packages (from pytesseract) (24.0)

# %%
import fitz  # PyMuPDF
import pytesseract
from PIL import Image
import os

# !! IMPORTANT !!
# You might need to set the path to the Tesseract executable
# if it's not in your system's PATH.
# For example (Windows):
# pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'
# For example (Linux):
# pytesseract.tesseract_cmd = r'/usr/bin/tesseract'
# Check your Tesseract installation path and uncomment/modify the line below if needed.
# pytesseract.tesseract_cmd = r'YOUR_TESSERACT_PATH\tesseract.exe' # <--- Modify this if needed

def ocr_pdf(pdf_path, txt_path):
    """
    Performs OCR on each page of a PDF and saves the extracted text.

    Args:
        pdf_path (str): The path to the input PDF file.
        txt_path (str): The path to the output text file.
    """
    doc = None # Initialize doc to None
    try:
        # Open the PDF document
        doc = fitz.open(pdf_path)
        full_ocr_text = ""

        print(f"Starting OCR for '{pdf_path}'...")

        # Iterate through each page
        for page_num in range(doc.page_count):
            page = doc.load_page(page_num)  # Load the current page

            # Convert the page to an image (pixmap)
            # You can adjust dpi for higher resolution, e.g., scale=2 for 144 dpi
            pixmap = page.get_pixmap()

            # Convert the pixmap to a PIL Image
            img = Image.frombytes("RGB", [pixmap.width, pixmap.height], pixmap.samples)

            # Perform OCR on the image using pytesseract
            try:
                page_text = pytesseract.image_to_string(img)
                print(f"Processed page {page_num + 1}/{doc.page_count}")

                # Add markers like you provided
                full_ocr_text += f"==Start of OCR for page {page_num + 1}==\n"
                full_ocr_text += page_text
                full_ocr_text += f"\n==End of OCR for page {page_num + 1}==\n\n"

            except pytesseract.TesseractNotFoundError:
                 print("Error: Tesseract is not installed or not in your PATH.")
                 print("Please install Tesseract OCR engine and/or set the pytesseract.tesseract_cmd path.")
                 return
            except Exception as e:
                 print(f"An error occurred during OCR on page {page_num + 1}: {e}")
                 # Optionally, skip this page or stop

        # Write the extracted text to a .txt file
        with open(txt_path, "w", encoding="utf-8") as txt_file:
            txt_file.write(full_ocr_text)

        print(f"Successfully extracted text from '{pdf_path}' to '{txt_path}' using OCR.")

    except FileNotFoundError:
        print(f"Error: PDF file not found at '{pdf_path}'")
        print("Please check the input PDF path.")
    except Exception as e:
        print(f"An error occurred: {e}")
    finally:
        # Ensure the document is closed
        if doc:
             doc.close()

# --- Configuration ---
# !! IMPORTANT !!
# Replace 'your_input_file.pdf' with the actual path to your PDF file.
# Make sure the PDF file is accessible from where you run the script.
input_pdf_file = 'sdg.pdf'

# Replace 'output_ocr_text_file.txt' with the desired name for the output text file.
output_text_file = 'output_ocr_text_file.txt'

# --- Run the OCR conversion ---
if __name__ == "__main__":
    if os.path.exists(input_pdf_file):
        ocr_pdf(input_pdf_file, output_text_file)
    else:
        print(f"Error: Input PDF file not found at '{input_pdf_file}'.")
        print("Please update the 'input_pdf_file' variable with the correct path.")
# Out:
# Starting OCR for 'sdg.pdf'...
# Processed page 1/20
# Processed page 2/20
# Processed page 3/20
# Processed page 4/20
# Processed page 5/20
# Processed page 6/20
# Processed page 7/20
# Processed page 8/20
# Processed page 9/20
# Processed page 10/20
# Processed page 11/20
# Processed page 12/20
# Processed page 13/20
# Processed page 14/20
# Processed page 15/20
# Processed page 16/20
# Processed page 17/20
# Processed page 18/20
# Processed page 19/20
# Processed page 20/20
# Successfully extracted text from 'sdg.pdf' to 'output_ocr_text_file.txt' using OCR.
